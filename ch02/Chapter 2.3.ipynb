# %%
# !ls names
# Out:
# NationalReadMe.pdf  yob1891.txt  yob1903.txt  yob1915.txt  yob1927.txt	yob1939.txt  yob1951.txt  yob1963.txt  yob1975.txt  yob1987.txt  yob1999.txt
# yob1880.txt	    yob1892.txt  yob1904.txt  yob1916.txt  yob1928.txt	yob1940.txt  yob1952.txt  yob1964.txt  yob1976.txt  yob1988.txt  yob2000.txt
# yob1881.txt	    yob1893.txt  yob1905.txt  yob1917.txt  yob1929.txt	yob1941.txt  yob1953.txt  yob1965.txt  yob1977.txt  yob1989.txt  yob2001.txt
# yob1882.txt	    yob1894.txt  yob1906.txt  yob1918.txt  yob1930.txt	yob1942.txt  yob1954.txt  yob1966.txt  yob1978.txt  yob1990.txt  yob2002.txt
# yob1883.txt	    yob1895.txt  yob1907.txt  yob1919.txt  yob1931.txt	yob1943.txt  yob1955.txt  yob1967.txt  yob1979.txt  yob1991.txt  yob2003.txt
# yob1884.txt	    yob1896.txt  yob1908.txt  yob1920.txt  yob1932.txt	yob1944.txt  yob1956.txt  yob1968.txt  yob1980.txt  yob1992.txt  yob2004.txt
# yob1885.txt	    yob1897.txt  yob1909.txt  yob1921.txt  yob1933.txt	yob1945.txt  yob1957.txt  yob1969.txt  yob1981.txt  yob1993.txt  yob2005.txt
# yob1886.txt	    yob1898.txt  yob1910.txt  yob1922.txt  yob1934.txt	yob1946.txt  yob1958.txt  yob1970.txt  yob1982.txt  yob1994.txt  yob2006.txt
# yob1887.txt	    yob1899.txt  yob1911.txt  yob1923.txt  yob1935.txt	yob1947.txt  yob1959.txt  yob1971.txt  yob1983.txt  yob1995.txt  yob2007.txt
# yob1888.txt	    yob1900.txt  yob1912.txt  yob1924.txt  yob1936.txt	yob1948.txt  yob1960.txt  yob1972.txt  yob1984.txt  yob1996.txt  yob2008.txt
# yob1889.txt	    yob1901.txt  yob1913.txt  yob1925.txt  yob1937.txt	yob1949.txt  yob1961.txt  yob1973.txt  yob1985.txt  yob1997.txt  yob2009.txt
# yob1890.txt	    yob1902.txt  yob1914.txt  yob1926.txt  yob1938.txt	yob1950.txt  yob1962.txt  yob1974.txt  yob1986.txt  yob1998.txt  yob2010.txt

# %%
import pandas as pd
import numpy as np

names1880 = pd.read_csv('names/yob1880.txt', names=['name', 'sex', 'births'])

# %%
names1880
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 0 to 1999
# Data columns:
# name      2000  non-null values
# sex       2000  non-null values
# births    2000  non-null values
# dtypes: int64(1), object(2)

# %%
names1880.groupby('sex').births.sum()
# Out:
# sex
# F       90993
# M      110493
# Name: births

# %%
import re
import glob

# Assemble all of the data into a single DataFrame
years = range(1880, 2011)
pieces = []
columns = ['name', 'sex', 'births']

yob_filename_re = re.compile(r"yob(\d{4})")

yobs = glob.glob("names/yob*.txt")

for path in yobs:
    year = yob_filename_re.findall(path)[0]
    frame = pd.read_csv(path, names=columns)
    
    frame['year'] = int(year)
    pieces.append(frame)

# Concatenate everything into a single DataFrame
names = pd.concat(pieces, ignore_index=True)

# %%
names
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1690784 entries, 0 to 1690783
# Data columns:
# name      1690784  non-null values
# sex       1690784  non-null values
# births    1690784  non-null values
# year      1690784  non-null values
# dtypes: int64(2), object(2)

# %%
total_births = names.pivot_table('births', rows='year', cols='sex', aggfunc=sum)
total_births.tail()
# Out:
# sex         F        M
# year
# 2006  1896468  2050234
# 2007  1916888  2069242
# 2008  1883645  2032310
# 2009  1827643  1973359
# 2010  1759010  1898382

# %%
def add_prop(group):
    births = group.births.astype(float)
    
    group['prop'] = births / births.sum()
    return group
names = names.groupby(['year', 'sex']).apply(add_prop)

# %%
np.allclose(names.groupby(['year', 'sex']).prop.sum(), 1)
# Out:
# True

# %%
def get_top1000(group):
    return group.sort_index(by='births', ascending=False)[:1000]

# %%
grouped = names.groupby(['year', 'sex'])
top1000 = grouped.apply(get_top1000)

# %%
top1000
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 261877 entries, (1880, F, 1630694) to (2010, M, 672507)
# Data columns:
# name      261877  non-null values
# sex       261877  non-null values
# births    261877  non-null values
# year      261877  non-null values
# prop      261877  non-null values
# dtypes: float64(1), int64(2), object(2)

# %% [markdown]
# ## Analyzing Naming Trends

# %%
boys = top1000[top1000.sex == 'M']
girls = top1000[top1000.sex == 'F']

# %%
boys
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 130997 entries, (1880, M, 1631636) to (2010, M, 672507)
# Data columns:
# name      130997  non-null values
# sex       130997  non-null values
# births    130997  non-null values
# year      130997  non-null values
# prop      130997  non-null values
# dtypes: float64(1), int64(2), object(2)

# %%
total_births = top1000.pivot_table('births', rows='year', cols='name', aggfunc=sum)

# %%
subset = total_births[['Carolyn', 'Kyle', 'Chloe', 'Greg', 'Laura']]
subset.plot(subplots=True, figsize=(12,10), grid=False, title="Number of births per year")
# Out:
# array([<matplotlib.axes.AxesSubplot object at 0xc9dbdd0>,
#        <matplotlib.axes.AxesSubplot object at 0x763de50>,
#        <matplotlib.axes.AxesSubplot object at 0xa1c3450>,
#        <matplotlib.axes.AxesSubplot object at 0x736c790>,
#        <matplotlib.axes.AxesSubplot object at 0x737fc50>], dtype=object)

# %% [markdown]
# ### Measuring the increase in naming diversity

# %%
table = top1000.pivot_table('prop', rows='year', cols='sex', aggfunc=sum)

# %%
table.plot(title='Sum of table1000.prop by year and sex', yticks=np.linspace(0,1.2,13), xticks=range(1880, 2020, 10))

# %%
df = boys[boys.year == 2010]

# %%
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1000 entries, (2010, M, 671508) to (2010, M, 672507)
# Data columns:
# name      1000  non-null values
# sex       1000  non-null values
# births    1000  non-null values
# year      1000  non-null values
# prop      1000  non-null values
# dtypes: float64(1), int64(2), object(2)

# %%
prop_cumsum = df.sort_index(by='prop', ascending=False).prop.cumsum()
prop_cumsum[:10]
# Out:
# year  sex
# 2010  M    671508    0.011523
#            671509    0.020934
#            671510    0.029959
#            671511    0.038930
#            671512    0.047817
#            671513    0.056579
#            671514    0.065155
#            671515    0.073414
#            671516    0.081528
#            671517    0.089621

# %%
prop_cumsum.searchsorted(0.5)
# Out:
# 116

# %%
df = boys[boys.year == 1900]
in1900 = df.sort_index(by='prop', ascending=False).prop.cumsum()
in1900.searchsorted(0.5) + 1
# Out:
# 25

# %%
def get_quantile_count(group, q=0.5):
    group = group.sort_index(by='prop', ascending=False)
    return group.prop.cumsum().searchsorted(q) + 1

diversity = top1000.groupby(['year', 'sex']).apply(get_quantile_count)
diversity = diversity.unstack('sex')

# %%
diversity.head()
# Out:
# sex    F   M
# year
# 1880  38  14
# 1881  38  14
# 1882  38  15
# 1883  39  15
# 1884  39  16

# %%
diversity.plot(title="Number of popular nmaes in top 50%")

# %% [markdown]
# ### The "Last letter" Revolution

# %%
# extract last letter from name column
get_last_letter = lambda x: x[-1]
last_letters = names.name.map(get_last_letter)
last_letters.name = 'last_letter'

table = names.pivot_table('births', rows=last_letters, cols=['sex', 'year'], aggfunc=sum)

# %%
subtable = table.reindex(columns=[1910, 1960, 2010], level='year')
subtable.head()
# Out:
# sex               F                      M
# year           1910    1960    2010   1910    1960    2010
# last_letter
# a            108376  691247  670605    977    5204   28438
# b               NaN     694     450    411    3912   38859
# c                 5      49     946    482   15476   23125
# d              6750    3729    2607  22111  262112   44398
# e            133569  435013  313833  28655  178823  129012

# %%
subtable.sum()
# Out:
# sex  year
# F    1910     396416
#      1960    2022062
#      2010    1759010
# M    1910     194198
#      1960    2132588
#      2010    1898382

# %%
# Time to normalize by total births
letter_prop = subtable / subtable.sum().astype(float)

# %%
fig, axes = plt.subplots(2,1, figsize=(10,8))
letter_prop['M'].plot(kind='bar', rot=0, ax=axes[0], title='Male')
letter_prop['F'].plot(kind='bar', rot=0, ax=axes[1], title='Female', legend=False)

# %%
# Back to the full table, normalize by year and sex and select a subset of letters for the boy names, transposing to make each column a time series
letter_prop = table / table.sum().astype(float)
dny_ts = letter_prop.ix[['d', 'n', 'y'], 'M'].T
dny_ts.head()
# Out:
#              d         n         y
# year
# 1880  0.083055  0.153213  0.075760
# 1881  0.083247  0.153214  0.077451
# 1882  0.085340  0.149560  0.077537
# 1883  0.084066  0.151646  0.079144
# 1884  0.086120  0.149915  0.080405

# %%
dny_ts.plot(title="Proportion of males born with names ending in d, n, or y over time")

# %% [markdown]
# ### Boy names that became girl names (and vice versa)

# %%
all_names = top1000.name.unique()
mask = np.array(['lesl' in x.lower() for x in all_names])
lesley_like = all_names[mask]
lesley_like
# Out:
# array(['Leslie', 'Lesley', 'Leslee', 'Lesli', 'Lesly'], dtype=object)

# %%
filtered = top1000[top1000.name.isin(lesley_like)]
filtered.groupby('name').births.sum()
# Out:
# name
# Leslee      1082
# Lesley     35022
# Lesli        929
# Leslie    370429
# Lesly      10067
# Name: births

# %%
table = filtered.pivot_table('births', rows='year', cols='sex', aggfunc='sum')
table = table.div(table.sum(1), axis=0)
table.tail()
# Out:
# sex   F   M
# year
# 2006  1 NaN
# 2007  1 NaN
# 2008  1 NaN
# 2009  1 NaN
# 2010  1 NaN

# %%
table.plot(style={'M': 'k-', 'F': 'k--'}, title='Proportion of male/female Lesley-like names over time')
