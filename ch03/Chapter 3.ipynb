# %%
# %run cprof_example.py
# Out:
# Largest one we saw: 11.6627639238

# %%
# %prun -l 7 -s cumulative run_experiment()

# %%
# %run -p -s cumulative cprof_example.py
# Out:
# Largest one we saw: 12.3016451807

# %% [markdown]
# **Note:**
#
# For this section I created a new ipython configuration specific to this project by running
#
# ```$ ipython profile create pydata```
#
# then I added
#
# ```c.TerminalIPythonApp.extensions = ['line_profiler']```
#
# to `~/.config/ipython/profile_pydata/ipython_config.py`
#
# and made sure to set my profile when loading ipython
#
# ```$ ipython --profile=pydata```

# %%
# %run prof_mod
x = randn(3000, 3000)
y = randn(3000, 3000)
# %prun add_and_sum(x,y)

# %%
# %lprun -f add_and_sum add_and_sum(x,y)
# Out:
# ERROR: Line magic function `%lprun` not found.

# %%
# Well darn. It worked on an IPython terminal, but not in the notebook...

# %%
img = plt.imread('stinkbug.png')
figure(figsize=(4,4))
plt.imshow(img)
